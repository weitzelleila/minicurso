# %% [markdown]
# # Exercicio optuna
#
# * aproveite o modelo criar na exercicio com Yelp (aula modelo simples) e utilize o optuna para encontrar os melhores parametros.
# * compare os resultados dos dois métodos.
# * Faça uma analise dos resultados
