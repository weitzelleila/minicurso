# %% [markdown]
# # Exercicio para balanceamento de uma base de dados
#
# * sampled_datasetYelp.csv
# * fazer o balanceamento da base de dados
# * são 3 classes de saida, positive, negative e neutral
# * voces devem balancear apenas para duas classes positive e negative, retirar a classe neutral.
